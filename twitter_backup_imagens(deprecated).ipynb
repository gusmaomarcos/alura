# %% [markdown]
# <a href="https://colab.research.google.com/github/gusmaomarcos/alura/blob/main/twitter_backup_imagens(deprecated).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
consumer_key = 'g9exuR9PRNqIWIRLJIf3oJfJs'
consumer_secret = 'wOerWipBknVJpbBs5lKDdRbC7CfAcW746CaJOqcRWz5V3ZbLFj'
#bearer_token = 'AAAAAAAAAAAAAAAAAAAAAJYnSAEAAAAAjEXwhteLbI7sImSdyoNYsmV%2FSrI%3DeMtnzlO9zXyLYEnF70bzkQYy18RLODHmdcslrKJRO24k8qysXS'

access_token = '1052371262008373248-y1cBFZACngH1pESipIZoIe73hGS3bS'
access_token_secret = 'ZrnbeLouuqv6OrQWqFHIWyFyt6jYhsSwRyezzyI9bFrvj'

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# @OgaMendonca A vibração de peruano foi massa demais!
# RT @brunoruchiga: tou na twitch trabalhando no meu projeto de party game online inspirado por uma mistura entre Stop e Adedanha Maluca com…
# RT @claudiorubio: tempo seco.
#
# #adote o Bento: srd, adulto, 20kg, vacinado, castrado. Casa Verde, São Paulo, SP. 11-3966-2944, com Cristina…
# Absolute brilliance. Do not sleep on this, USA friends. https://t.co/4g6t2mlf9d
# BH motivado depois do gol anulado, um atleta que injustiçado rende mais. O Renato com certeza tem que continuar tra… https://t.co/rsrMYgbFZp
# @kenfujioka Sim! Mas na competição a vibe desses competidores era muito tranquila, um vibrando quando o outro acertava algo muito difícil.
# Renato Gaúcho tem o melhor início de técnico do Flamengo no século 21 | blog do pvc | ge https://t.co/gTJIY8Ij0c
# Enrayssado total eu tô aqui… https://t.co/mSBIAeaXKD
# Dança muito a Maria Joana.
# vou fazer um hot dig hoje
# ...

# %%
api.me()
# Out:
# User(_api=<tweepy.api.API object at 0x7f63f35f0f50>, _json={'id': 1052371262008373248, 'id_str': '1052371262008373248', 'name': 'vinicius', 'screen_name': 'gusmaomarcso', 'location': 'Rio de Janeiro, Brasil', 'profile_location': {'id': '97bcdfca1a2dca59', 'url': 'https://api.twitter.com/1.1/geo/id/97bcdfca1a2dca59.json', 'place_type': 'unknown', 'name': 'Rio de Janeiro, Brasil', 'full_name': 'Rio de Janeiro, Brasil', 'country_code': '', 'country': '', 'contained_within': [], 'bounding_box': None, 'attributes': {}}, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 93, 'listed_count': 0, 'created_at': 'Wed Oct 17 01:30:35 +0000 2018', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 435, 'lang': None, 'status': {'created_at': 'Sat Jul 17 17:48:31 +0000 2021', 'id': 1416454783343415298, 'id_str': '1416454783343415298', 'text': '#Ass
# ...

# %%
api.home_timeline()
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f63f35f0f50>, _json={'created_at': 'Sun Jul 25 23:17:47 +0000 2021', 'id': 1419436748766076929, 'id_str': '1419436748766076929', 'text': 'eiii se ligue que hoje eh dia de skate 🛹🔥', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 885868623994245120, 'id_str': '885868623994245120', 'name': 'paulo moreira', 'screen_name': 'paulomoreria', 'location': 'João Pessoa, Brasil', 'description': 'estou postando bom dia socorro viu, é meu quadrinho e tá aí no fixado! ! !', 'url': 'https://t.co/M9fzOm9290', 'entities': {'url': {'urls': [{'url': 'https://t.co/M9fzOm9290', 'expanded_url': 'http://instagram.com/paulomoreirap', 'display_url'
# ...

# %%
import pandas as pd

# %%
df = api.user_timeline(count=500)

# %%
df2 = pd.DataFrame(df)

# %%
df2.head(3)
# Out:
#                                                    0
# 0  Status(_api=<tweepy.api.API object at 0x7f63f3...
# 1  Status(_api=<tweepy.api.API object at 0x7f63f3...
# 2  Status(_api=<tweepy.api.API object at 0x7f63f3...
